# %%
import math

# %% [markdown]
# ## Strings

# %% [markdown]
# ### Slicing

# %%
name = 'My name is Honey Chauhan'

# %%
name[0]

# %%
name[1]

# %%
name[0:7]

# %%
name[:7]

# %%
name[11:]

# %%
myList = [1,2,3,4,5]

# %%
myList[2:4]

# %%
len(name)

# %%
len(myList)

# %% [markdown]
# ### Formatting

# %%
'My number is: '+str(5)

# %%
f'My number is: {5}'

# %%
f'My number is: {5} and twice that is {2*5}'

# %%
f'Pi is: {math.pi:.2f}'

# %%
'Pi is: {}'.format(math.pi)

# %% [markdown]
# ### Multi-line Strings

# %%
myString = '''
Here is a long block of text
I can add newlines!
the text doesn't stop until it sees \'''\n
'''

# %%
myString

# %%
print(myString)

# %% [markdown]
# ### Bytes

# %%
bytes(4)

# %%
smileyBytes = bytes('🙄', 'utf-8')
smileyBytes

# %%
smileyBytes.decode('utf-8')

# %%
smileyBytes = bytearray('🙄', 'utf-8')

# %%
smileyBytes

# %%
smileyBytes[3] = int('85', 16)

# %%
smileyBytes.decode('utf-8')
