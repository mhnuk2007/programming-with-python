# %% [markdown]
# ## Ints and Floats

# %%
20 / 4

# %%
4 + 4.0

# %%
4 * 4.0

# %%
4 ** 4.0

# %%
int(4 ** 4.0)

# %%
int(8.9)

# %%
int(8.99999999)

# %%
int(14/3)

# %%
round(14/3, 2)

# %%
1.2 - 1.0

# %%
14/3

# %%
round(1.2 - 1.0, 2)
