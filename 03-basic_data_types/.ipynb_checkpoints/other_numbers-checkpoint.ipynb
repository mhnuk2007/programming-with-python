# %%
from decimal import Decimal, getcontext

# %% [markdown]
# ## Integers

# %%
int('100')

# %%
int('100', 2)

# %%
int(100, 2)

# %%
int('1ab', 16)

# %%
1.2 - 1.0

# %% [markdown]
# ## Decimals

# %%
getcontext()

# %%
getcontext().prec=4

# %%
getcontext()

# %%
Decimal(1) / Decimal(3)

# %%
getcontext().prec=2

# %%
Decimal(1) / Decimal(3)

# %%
Decimal(3.14)

# %%
Decimal('3.14')

# %%
round(1.2 - 1.0, 2)
