# %% [markdown]
# # Basic Data Types

# %% [markdown]
# ## Defining a variable

# %%
x = 5

# %%
print(x)
# Out:
# 5

# %%
x
# Out:
# 5

# %%
name = 'honey'

# %%
print(name)
# Out:
# honey

# %%
name
# Out:
# 'honey'

# %% [markdown]
# ## Numbers

# %%
type(5)
# Out:
# int

# %%
type(1.5)
# Out:
# float

# %%
type(1.)
# Out:
# float

# %%
type(2j)
# Out:
# complex

# %%
1j*1j
# Out:
# (-1+0j)

# %%
(1+1j)*(1+1j)
# Out:
# 2j

# %%
1 + '1'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 1 + '1'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(1 + '1')

# %% [markdown]
# ## Strings

# %%
print('string1')
# Out:
# string1

# %%
'str1' + 'str2'
# Out:
# 'str1str2'

# %% [markdown]
# ## Booleans

# %%
True
# Out:
# True

# %%
a = True
b = False
a + b
# Out:
# 1

# %%
b + b
# Out:
# 0

# %%
print(a+b)
type(a+b)
# Out:
# 1
# int
