# %% [markdown]
# # Basic Data Types

# %% [markdown]
# ## Defining a variable

# %%
x = 5

# %%
print(x)

# %%
x

# %%
name = 'honey'

# %%
print(name)

# %%
name

# %% [markdown]
# ## Numbers

# %%
type(5)

# %%
type(1.5)

# %%
type(1.)

# %%
type(2j)

# %%
1j*1j

# %%
(1+1j)*(1+1j)

# %%
1 + '1'

# %%
print(1 + '1')

# %% [markdown]
# ## Strings

# %%
print('string1')

# %%
'str1' + 'str2'

# %% [markdown]
# ## Booleans

# %%
True

# %%
a = True
b = False
a + b

# %%
b + b

# %%
print(a+b)
type(a+b)
