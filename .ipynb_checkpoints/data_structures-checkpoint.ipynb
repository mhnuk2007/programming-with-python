# %% [markdown]
# # Data Structures

# %% [markdown]
# ## Lists

# %%
my_list = [1,2,3,4]
print(my_list)

# %%
my_list = ['list', 'of', 'strings']
print(my_list) 
my_list

# %%
my_list = [1, 'list', False, []]
print(my_list) 
my_list

# %%
len(my_list)

# %% [markdown]
# ## Set

# %%
my_set = {1,2,3,4,5}
print(my_set)

# %%
type(my_set)

# %%
len(my_set)

# %%
my_set = {1,1,2,2}
len(my_set)
print(my_set)

# %%
[1,2] == [2,1]

# %%
{1,2} == {2,1}

# %%
{1,2,3} == {3,2,1,1,1}

# %%
my_tuple = (1,2,3)

# %%
len(my_tuple)

# %%
(1,2) == (2,1)

# %%
my_list.append(6)
print(my_list)

# %%
my_tuple.append(4)

# %% [markdown]
# ## Dictionaries

# %%
my_dictionary = {
    'apple': 'A red fruit', 
    'bear': 'A scary animal'
}
my_dictionary

# %%
my_dictionary['apple']

# %%
my_dictionary['bear']
